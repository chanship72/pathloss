# %%
# %load_ext autoreload
# %autoreload

import numpy as np
import pandas as pd
import pickle

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, GroupKFold
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score

from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns
import random

from equationmodel_ann import ann_mlp_regression, prediction_rmse_error, ann_linear_compare_graph, errorDist
from util import ADD_data_loader, combineDF, filteringDF, getFreeSpacePathLoss, makeXforGraphWithGroupingFrequency,\
                makeXforGraph, inverseScale, samplingData, normalizeData,train_2d_graph, train_3d_graph

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

desired_width=620
pd.set_option('display.width', desired_width)
pd.set_option('display.max_columns',30)
pd.options.display.float_format = "{:.2f}".format

# %%
# %autoreload

wt_fileList = {'../data/PLdata_paju_wt_400.csv':[('season', 0), ('frequency', 400), ('heightTB',100), ('heightB',7), ('heightM',2)],
            '../data/PLdata_paju_wt_1399.csv':[('season', 0), ('frequency', 1399), ('heightTB',100), ('heightB',7), ('heightM',2)],
            '../data/PLdata_paju_wt_2249.csv':[('season', 0), ('frequency', 2249), ('heightTB',100), ('heightB',7), ('heightM',2)]}
sp_fileList = {'../data/PLdata_paju_sp_400.csv':[('season', 0.5), ('frequency', 400), ('heightTB',100), ('heightB',7), ('heightM',2)],
            '../data/PLdata_paju_sp_1399.csv':[('season', 0.5), ('frequency', 1399), ('heightTB',100), ('heightB',7), ('heightM',2)],
            '../data/PLdata_paju_sp_2249.csv':[('season', 0.5), ('frequency', 2249), ('heightTB',100), ('heightB',7), ('heightM',2)]}
sm_fileList = {'../data/PLdata_paju_sm_400.csv':[('season', 1.0), ('frequency', 400), ('heightTB',100), ('heightB',7), ('heightM',2)],
            '../data/PLdata_paju_sm_1399.csv':[('season', 1.0), ('frequency', 1399), ('heightTB',100), ('heightB',7), ('heightM',2)],
            '../data/PLdata_paju_sm_2249.csv':[('season', 1.0), ('frequency', 2249), ('heightTB',100), ('heightB',7), ('heightM',2)]}
addWt = ADD_data_loader(wt_fileList)
print("winter data:",addWt.shape)
print("")
addSp = ADD_data_loader(sp_fileList)
print("spring data:",addSp.shape)
print("")
addSm = ADD_data_loader(sm_fileList)
print("summer data:",addSm.shape)
print("")

# print(addIksan.describe())
# print(addNonsan.describe())
# print(addPaju.describe())

addData = combineDF([addWt, addSp, addSm])
print("antenna_b height filtering-before(data count):",addData.shape)
addData = filteringDF(addData, 'heightTM', [10,100])
print("antenna_b height filtering-after(data count):",addData.shape)

print("freespace pathloss filtering-before(data count):",addData.shape)
addData['freePathloss'] = getFreeSpacePathLoss(addData['distance'],addData['frequency'])
addData = addData[addData['pathloss'] >= addData['freePathloss']]
print("freespace pathloss filtering-after(data count):",addData.shape)

# print("ADD data sample:\n",addData.head())
# Out:
# ADD data preprocessing
# ../data/PLdata_paju_wt_2249.csv: distance filtering(before):(110246, 4)
# ../data/PLdata_paju_wt_2249.csv: distance filtering(after):(22505, 4)
# ../data/PLdata_paju_wt_400.csv: distance filtering(before):(110440, 4)
# ../data/PLdata_paju_wt_400.csv: distance filtering(after):(22532, 4)
# ../data/PLdata_paju_wt_1399.csv: distance filtering(before):(110358, 4)
# ../data/PLdata_paju_wt_1399.csv: distance filtering(after):(22518, 4)
#         type  distance  pathloss  heightTM  season  frequency  heightTB  heightB  heightM
# type 93    m      1.00    107.14      0.02       0       2249       100        7        2
#      94    m      1.01    105.75      0.02       0       2249       100        7        2
#      95    m      1.01    103.32      0.02       0       2249       100        7        2
#      96    m      1.01    103.28      0.02       0       2249       100        7        2
#      97    m      1.01    103.61      0.02       0       2249       100        7        2
# Combined data set: (67555, 9)
# type filtering(before):(67555, 9)
# type filtering(after):(50752, 9)
# Dataframe before add new terms: (50752, 9)
# Dataframe after add constant feature: (50752, 20)
# winter data: (50752, 20)
#
# ADD data preprocessing
# ../data/PLdata_paju_sp_2249.csv: distance filtering(before):(90428, 4)
# ../data/PLdata_paju_sp_2249.csv: distance filtering(after):(16534, 4)
# ../data/PLdata_paju_sp_1399.csv: distance filtering(before):(90501, 4)
# ../data/PLdata_paju_sp_1399.csv: distance filtering(after):(16534, 4)
# ../data/PLdata_paju_sp_400.csv: distance filtering(before):(90557, 4)
# ../data/PLdata_paju_sp_400.csv: distance filtering(after):(16534, 4)
#          type  distance  pathloss  heightTM  season  frequency  heightTB  heightB  heightM
# type 271    m      1.00     99.19      0.02    0.50       2249       100        7        2
#      272    m      1.00     99.52      0.02    0.50       2249       100        7        2
#      273    m      1.00    100.38      0.02    0.50       2249       100        7        2
#      274    m      1.00    102.94      0.02    0.50       2249       100        7        2
#      275    m      1.00    114.93      0.02    0.50       2249       100        7        2
# Combined data set: (49602, 9)
# type filtering(before):(49602, 9)
# type filtering(after):(24840, 9)
# Dataframe before add new terms: (24840, 9)
# Dataframe after add constant feature: (24840, 20)
# spring data: (24840, 20)
#
# ADD data preprocessing
# ../data/PLdata_paju_sm_400.csv: distance filtering(before):(109969, 4)
# ../data/PLdata_paju_sm_400.csv: distance filtering(after):(26440, 4)
# ../data/PLdata_paju_sm_1399.csv: distance filtering(before):(109891, 4)
# ../data/PLdata_paju_sm_1399.csv: distance filtering(after):(26425, 4)
# ../data/PLdata_paju_sm_2249.csv: distance filtering(before):(109754, 4)
# ../data/PLdata_paju_sm_2249.csv: distance filtering(after):(26409, 4)
#          type  distance  pathloss  heightTM  season  frequency  heightTB  heightB  heightM
# type 290    m      1.02     88.62      0.02    1.00        400       100        7        2
#      291    m      1.02     88.61      0.02    1.00        400       100        7        2
#      292    m      1.03     88.61      0.02    1.00        400       100        7        2
#      293    m      1.03     88.61      0.02    1.00        400       100        7        2
#      294    m      1.04     88.61      0.02    1.00        400       100        7        2
# Combined data set: (79274, 9)
# type filtering(before):(79274, 9)
# type filtering(after):(62336, 9)
# Dataframe before add new terms: (62336, 9)
# Dataframe after add constant feature: (62336, 20)
# summer data: (62336, 20)
#
# antenna_b height filtering-before(data count): (137928, 20)
# antenna_b height filtering-after(data count): (125944, 20)
# freespace pathloss filtering-before(data count): (125944, 20)
# freespace pathloss filtering-after(data count): (123134, 20)

# %%
# %autoreload

targetCols = ['logDistance', 'logFrequency', 'logExtendedHeightTratio', 'season', 'pathloss']
xCols = ['logDistance', 'logFrequency', 'logExtendedHeightTratio', 'season',]
yCols = 'pathloss'
scale = "manual"
stat = {}
i = 1

sampleRange = np.arange(0.001, 1.0, 0.1)
for sampleRatio in sampleRange:
    rmse_sum = 0

    addDataSampled = samplingData(addData[targetCols], sampleRatio, None, prFlag = False, randomState = i)
    # addDataSample.sort_values(by=['logDistance'])
    print("sample size:",addDataSampled['pathloss'].count())
    addDataNorm, normalizer = normalizeData(addDataSampled[targetCols], addDataSampled[yCols], scaler = scale, prFlag = False)

    X = np.array(addDataNorm[xCols])
    Xorigin = np.array(addData[xCols]) 
    Y = np.array(addDataSampled[yCols])

    kf = KFold(n_splits=5, shuffle=True)
    bestTestError = 0
    bestModel = None

    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = Y[train_index], Y[test_index]    
        model = ann_mlp_regression((60,), activation='logistic', optimizer='lbfgs')
        model.fit(X_train, y_train.flatten())

        pred_test = model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        mae = mean_absolute_error(y_test, pred_test)
        mape = mean_absolute_percentage_error(y_test, pred_test)
        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        r2 = r2_score(y_test, pred_test)
#         print("#"+str(i)+" Error(RMSE)-train:{} / test:{}".format(trainError,testError))     

        rmse_sum += rmse

        i+=1
    avgRMSE = rmse_sum / 5
    print("sampleRatio:",sampleRatio)
#     print("Worst Model:",worstModel)
    print("Average Test Error(RMSE):",avgRMSE)
    stat[sampleRatio] = avgRMSE
# Out:
# sample size: 123
# sampleRatio: 0.001
# Average Test Error(RMSE): 24.35055355214858
# sample size: 12437
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2880: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)
# sampleRatio: 0.101
# Average Test Error(RMSE): 9.764792809396445
# sample size: 24750
# sampleRatio: 0.201
# Average Test Error(RMSE): 9.588097774743563
# sample size: 37063
# sampleRatio: 0.30100000000000005
# Average Test Error(RMSE): 9.56058361973655
# sample size: 49377
# sampleRatio: 0.401
# Average Test Error(RMSE): 9.533934539013547
# sample size: 61690
# sampleRatio: 0.501
# Average Test Error(RMSE): 9.550428118205039
# sample size: 74004
# sampleRatio: 0.6010000000000001
# Average Test Error(RMSE): 9.554548668782601
# sample size: 86317
# sampleRatio: 0.7010000000000001
# Average Test Error(RMSE): 9.48294796328419
# sample size: 98630
# sampleRatio: 0.801
# Average Test Error(RMSE): 9.562938292322837
# sample size: 110944
# sampleRatio: 0.901
# Average Test Error(RMSE): 9.519042128267486

# %%
print(stat)
# Out:
# {0.101: 9.709607388373968, 0.201: 9.585106458226315, 0.801: 9.516614340955979, 0.001: 22.19671733602862, 0.401: 9.565422653116206, 0.7010000000000001: 9.523567402758847, 0.6010000000000001: 9.51840788527536, 0.501: 9.549873452470129, 0.30100000000000005: 9.566250163531404, 0.901: 9.447740677943447}

# %%
df = pd.DataFrame(list(stat.items()), columns=['sampleRatio','RMSE']).sort_values(by=['sampleRatio'])
print(df)
df.plot.line(x='sampleRatio', y='RMSE')
# Out:
#    sampleRatio  RMSE
# 3         0.00 22.20
# 0         0.10  9.71
# 1         0.20  9.59
# 8         0.30  9.57
# 4         0.40  9.57
# 7         0.50  9.55
# 6         0.60  9.52
# 5         0.70  9.52
# 2         0.80  9.52
# 9         0.90  9.45

# %%
# %autoreload

targetCols = ['logDistance', 'logFrequency', 'logExtendedHeightTratio', 'season', 'pathloss']
xCols = ['logDistance', 'logFrequency', 'logExtendedHeightTratio', 'season',]
yCols = 'pathloss'
scale = "manual"
stat = {}

sampleRange = np.arange(0.001, 0.1, 0.005)
for sampleRatio in sampleRange:
    rmse_sum = 0

    addDataSampled = samplingData(addData[targetCols], sampleRatio, None, prFlag = False)
    # addDataSample.sort_values(by=['logDistance'])
    print("sample size:",addDataSampled['pathloss'].count())
    addDataNorm, normalizer = normalizeData(addDataSampled[targetCols], addDataSampled[yCols], scaler = scale, prFlag = False)

    X = np.array(addDataNorm[xCols])
    Xorigin = np.array(addData[xCols]) 
    Y = np.array(addDataSampled[yCols])

    kf = KFold(n_splits=5, shuffle=True)
    bestTestError = 0
    bestModel = None
    i = 1

    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = Y[train_index], Y[test_index]    
        model = ann_mlp_regression((60,), activation='logistic', optimizer='lbfgs')
        model.fit(X_train, y_train.flatten())

        pred_test = model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        mae = mean_absolute_error(y_test, pred_test)
        mape = mean_absolute_percentage_error(y_test, pred_test)
        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        r2 = r2_score(y_test, pred_test)
#         print("#"+str(i)+" Error(RMSE)-train:{} / test:{}".format(trainError,testError))     

        rmse_sum += rmse

        i+=1
    avgRMSE = rmse_sum / 5
    print("sampleRatio:",sampleRatio)
#     print("Worst Model:",worstModel)
    print("Average Test Error(RMSE):",avgRMSE)
    stat[sampleRatio] = avgRMSE
# Out:
# sample size: 123
# sampleRatio: 0.001
# Average Test Error(RMSE): 20.626457148890083
# sample size: 739
# sampleRatio: 0.006
# Average Test Error(RMSE): 12.398025473538423
# sample size: 1354
# sampleRatio: 0.011
# Average Test Error(RMSE): 10.953836811591724
# sample size: 1970
# sampleRatio: 0.016
# Average Test Error(RMSE): 10.267391146788931
# sample size: 2586
# sampleRatio: 0.021
# Average Test Error(RMSE): 10.267437189942548
# sample size: 3201
# sampleRatio: 0.026000000000000002
# Average Test Error(RMSE): 10.213959024220234
# sample size: 3817
# sampleRatio: 0.031
# Average Test Error(RMSE): 10.036693219005688
# sample size: 4433
# sampleRatio: 0.036000000000000004
# Average Test Error(RMSE): 10.05256663867046
# sample size: 5048
# sampleRatio: 0.041
# Average Test Error(RMSE): 9.833497910849431
# sample size: 5664
# sampleRatio: 0.046
# Average Test Error(RMSE): 9.841433786246904
# sample size: 6280
# sampleRatio: 0.051000000000000004
# Average Test Error(RMSE): 9.906650582532004
# sample size: 6896
# sampleRatio: 0.056
# Average Test Error(RMSE): 9.65004067562196
# sample size: 7511
# sampleRatio: 0.061
# Average Test Error(RMSE): 9.771989187580788
# sample size: 8127
# sampleRatio: 0.066
# Average Test Error(RMSE): 9.739212017636582
# sample size: 8743
# sampleRatio: 0.07100000000000001
# Average Test Error(RMSE): 9.652993171928218
# sample size: 9358
# sampleRatio: 0.076
# Average Test Error(RMSE): 9.706238198209729
# sample size: 9974
# sampleRatio: 0.081
# Average Test Error(RMSE): 9.694958958869979
# sample size: 10590
# sampleRatio: 0.08600000000000001
# Average Test Error(RMSE): 9.744917457333063
# sample size: 11205
# sampleRatio: 0.091
# Average Test Error(RMSE): 9.59958089342268
# sample size: 11821
# sampleRatio: 0.096
# Average Test Error(RMSE): 9.740165690766334

# %%
stat = {0.101: 9.709607388373968, 0.201: 9.585106458226315, 0.801: 9.516614340955979, 0.001: 22.19671733602862, 0.401: 9.565422653116206, 0.7010000000000001: 9.523567402758847, 0.6010000000000001: 9.51840788527536, 0.501: 9.549873452470129, 0.30100000000000005: 9.566250163531404, 0.901: 9.447740677943447, 0.016: 10.267391146788931, 0.046: 9.841433786246904, 0.056: 9.65004067562196, 0.076: 9.706238198209729, 0.036000000000000004: 10.05256663867046, 0.091: 9.59958089342268, 0.096: 9.740165690766334, 0.011: 10.953836811591724, 0.081: 9.694958958869979, 0.061: 9.771989187580788, 0.026000000000000002: 10.213959024220234, 0.041: 9.833497910849431, 0.08600000000000001: 9.744917457333063, 0.066: 9.739212017636582, 0.006: 12.398025473538423, 0.021: 10.267437189942548, 0.07100000000000001: 9.652993171928218, 0.051000000000000004: 9.906650582532004, 0.031: 10.036693219005688, 0.001: 20.626457148890083}
print(stat)

df = pd.DataFrame(list(stat.items()), columns=['sampleRatio','RMSE']).sort_values(by=['sampleRatio'])
print(df)
df.plot.line(x='sampleRatio', y='RMSE')
# Out:
# {0.101: 9.709607388373968, 0.201: 9.585106458226315, 0.091: 9.59958089342268, 0.061: 9.771989187580788, 0.6010000000000001: 9.51840788527536, 0.056: 9.65004067562196, 0.801: 9.516614340955979, 0.066: 9.739212017636582, 0.401: 9.565422653116206, 0.901: 9.447740677943447, 0.021: 10.267437189942548, 0.07100000000000001: 9.652993171928218, 0.031: 10.036693219005688, 0.016: 10.267391146788931, 0.076: 9.706238198209729, 0.036000000000000004: 10.05256663867046, 0.7010000000000001: 9.523567402758847, 0.011: 10.953836811591724, 0.081: 9.694958958869979, 0.501: 9.549873452470129, 0.041: 9.833497910849431, 0.08600000000000001: 9.744917457333063, 0.046: 9.841433786246904, 0.026000000000000002: 10.213959024220234, 0.001: 20.626457148890083, 0.096: 9.740165690766334, 0.006: 12.398025473538423, 0.051000000000000004: 9.906650582532004, 0.30100000000000005: 9.566250163531404}
#     sampleRatio  RMSE
# 24         0.00 20.63
# 26         0.01 12.40
# 17         0.01 10.95
# 13         0.02 10.27
# 10         0.02 10.27
# 23         0.03 10.21
# 12         0.03 10.04
# 15         0.04 10.05
# 20         0.04  9.83
# 22         0.05  9.84
# 27         0.05  9.91
# 5          0.06  9.65
# 3          0.06  9.77
# 7          0.07  9.74
# 11         0.07  9.65
# 14         0.08  9.71
# 18         0.08  9.69
# 21         0.09  9.74
# 2          0.09  9.60
# 25         0.10  9.74
# 0          0.10  9.71
# 1          0.20  9.59
# 28         0.30  9.57
# 8          0.40  9.57
# 19         0.50  9.55
# 4          0.60  9.52
# 16         0.70  9.52
# 6          0.80  9.52
# 9          0.90  9.45

# %%
# %autoreload

wt_fileList = {'../data/PLdata_nonsan_wt_400.csv':[('season', 0), ('frequency', 400), ('heightTB',30), ('heightB',15), ('heightM',2)],
            '../data/PLdata_nonsan_wt_1399.csv':[('season', 0), ('frequency', 1399), ('heightTB',30), ('heightB',15), ('heightM',2)],
            '../data/PLdata_nonsan_wt_2249.csv':[('season', 0), ('frequency', 2249), ('heightTB',30), ('heightB',15), ('heightM',2)]}
sp_fileList = {'../data/PLdata_nonsan_sp_400.csv':[('season', 0.5), ('frequency', 400), ('heightTB',30), ('heightB',15), ('heightM',2)],
            '../data/PLdata_nonsan_sp_1399.csv':[('season', 0.5), ('frequency', 1399), ('heightTB',30), ('heightB',15), ('heightM',2)],
            '../data/PLdata_nonsan_sp_2249.csv':[('season', 0.5), ('frequency', 2249), ('heightTB',30), ('heightB',15), ('heightM',2)]}
sm_fileList = {'../data/PLdata_nonsan_sm_400.csv':[('season', 1.0), ('frequency', 400), ('heightTB',30), ('heightB',15), ('heightM',2)],
            '../data/PLdata_nonsan_sm_1399.csv':[('season', 1.0), ('frequency', 1399), ('heightTB',30), ('heightB',15), ('heightM',2)],
            '../data/PLdata_nonsan_sm_2249.csv':[('season', 1.0), ('frequency', 2249), ('heightTB',30), ('heightB',15), ('heightM',2)]}
addWt = ADD_data_loader(wt_fileList)
print("winter data:",addWt.shape)
print("")
addSp = ADD_data_loader(sp_fileList)
print("spring data:",addSp.shape)
print("")
addSm = ADD_data_loader(sm_fileList)
print("summer data:",addSm.shape)
print("")

# print(addIksan.describe())
# print(addNonsan.describe())
# print(addPaju.describe())

addData = combineDF([addWt, addSp, addSm])
print("antenna_b height filtering-before(data count):",addData.shape)
addData = filteringDF(addData, 'heightTM', [10,100])
print("antenna_b height filtering-after(data count):",addData.shape)

print("freespace pathloss filtering-before(data count):",addData.shape)
addData['freePathloss'] = getFreeSpacePathLoss(addData['distance'],addData['frequency'])
addData = addData[addData['pathloss'] >= addData['freePathloss']]
print("freespace pathloss filtering-after(data count):",addData.shape)

# print("ADD data sample:\n",addData.head())
# Out:
# ADD data preprocessing
# ../data/PLdata_nonsan_wt_2249.csv: distance filtering(before):(114341, 4)
# ../data/PLdata_nonsan_wt_2249.csv: distance filtering(after):(10209, 4)
# ../data/PLdata_nonsan_wt_1399.csv: distance filtering(before):(114455, 4)
# ../data/PLdata_nonsan_wt_1399.csv: distance filtering(after):(10209, 4)
# ../data/PLdata_nonsan_wt_400.csv: distance filtering(before):(114545, 4)
# ../data/PLdata_nonsan_wt_400.csv: distance filtering(after):(10209, 4)
#          type  distance  pathloss  heightTM  season  frequency  heightTB  heightB  heightM
# type 389    m      1.01    125.16      0.02       0       2249        30       15        2
#      390    m      1.01    125.02      0.02       0       2249        30       15        2
#      391    m      1.01    123.00      0.02       0       2249        30       15        2
#      392    m      1.02    122.80      0.02       0       2249        30       15        2
#      393    m      1.03    122.53      0.02       0       2249        30       15        2
# Combined data set: (30627, 9)
# type filtering(before):(30627, 9)
# type filtering(after):(23295, 9)
# Dataframe before add new terms: (23295, 9)
# Dataframe after add constant feature: (23295, 20)
# winter data: (23295, 20)
#
# ADD data preprocessing
# ../data/PLdata_nonsan_sp_1399.csv: distance filtering(before):(98380, 4)
# ../data/PLdata_nonsan_sp_1399.csv: distance filtering(after):(5805, 4)
# ../data/PLdata_nonsan_sp_400.csv: distance filtering(before):(98432, 4)
# ../data/PLdata_nonsan_sp_400.csv: distance filtering(after):(5816, 4)
# ../data/PLdata_nonsan_sp_2249.csv: distance filtering(before):(98268, 4)
# ../data/PLdata_nonsan_sp_2249.csv: distance filtering(after):(5787, 4)
#          type  distance  pathloss  heightTM  season  frequency  heightTB  heightB  heightM
# type 181    m      1.01    123.01      0.03    0.50       1399        30       15        2
#      182    m      1.02    123.90      0.03    0.50       1399        30       15        2
#      183    m      1.02    116.11      0.03    0.50       1399        30       15        2
#      184    m      1.02    114.94      0.03    0.50       1399        30       15        2
#      185    m      1.03    127.12      0.03    0.50       1399        30       15        2
# Combined data set: (17408, 9)
# type filtering(before):(17408, 9)
# type filtering(after):(9833, 9)
# Dataframe before add new terms: (9833, 9)
# Dataframe after add constant feature: (9833, 20)
# spring data: (9833, 20)
#
# ADD data preprocessing
# ../data/PLdata_nonsan_sm_2249.csv: distance filtering(before):(112079, 4)
# ../data/PLdata_nonsan_sm_2249.csv: distance filtering(after):(8348, 4)
# ../data/PLdata_nonsan_sm_400.csv: distance filtering(before):(112337, 4)
# ../data/PLdata_nonsan_sm_400.csv: distance filtering(after):(8389, 4)
# ../data/PLdata_nonsan_sm_1399.csv: distance filtering(before):(112219, 4)
# ../data/PLdata_nonsan_sm_1399.csv: distance filtering(after):(8374, 4)
#          type  distance  pathloss  heightTM  season  frequency  heightTB  heightB  heightM
# type 489    m      1.01    135.51      0.02    1.00       2249        30       15        2
#      490    m      1.03    141.64      0.02    1.00       2249        30       15        2
#      491    m      1.03    135.94      0.02    1.00       2249        30       15        2
#      492    m      1.03    135.40      0.02    1.00       2249        30       15        2
#      493    m      1.04    133.15      0.02    1.00       2249        30       15        2
# Combined data set: (25111, 9)
# type filtering(before):(25111, 9)
# type filtering(after):(17875, 9)
# Dataframe before add new terms: (17875, 9)
# Dataframe after add constant feature: (17875, 20)
# summer data: (17875, 20)
#
# antenna_b height filtering-before(data count): (51003, 20)
# antenna_b height filtering-after(data count): (46542, 20)
# freespace pathloss filtering-before(data count): (46542, 20)
# freespace pathloss filtering-after(data count): (46289, 20)

# %%
# %autoreload

targetCols = ['logDistance', 'logFrequency', 'logExtendedHeightTratio', 'season', 'pathloss']
xCols = ['logDistance', 'logFrequency', 'logExtendedHeightTratio', 'season',]
yCols = 'pathloss'
scale = "manual"
stat = {}

sampleRange = np.arange(0.001, 1.0, 0.1)
for sampleRatio in sampleRange:
    rmse_sum = 0

    addDataSampled = samplingData(addData[targetCols], sampleRatio, None, prFlag = False)
    # addDataSample.sort_values(by=['logDistance'])
    print("sample size:",addDataSampled['pathloss'].count())
    addDataNorm, normalizer = normalizeData(addDataSampled[targetCols], addDataSampled[yCols], scaler = scale, prFlag = False)

    X = np.array(addDataNorm[xCols])
    Xorigin = np.array(addData[xCols]) 
    Y = np.array(addDataSampled[yCols])

    kf = KFold(n_splits=5, shuffle=True)
    bestTestError = 0
    bestModel = None
    i = 1

    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = Y[train_index], Y[test_index]    
        model = ann_mlp_regression((60,), activation='logistic', optimizer='lbfgs')
        model.fit(X_train, y_train.flatten())

        pred_test = model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        mae = mean_absolute_error(y_test, pred_test)
        mape = mean_absolute_percentage_error(y_test, pred_test)
        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        r2 = r2_score(y_test, pred_test)
#         print("#"+str(i)+" Error(RMSE)-train:{} / test:{}".format(trainError,testError))     

        rmse_sum += rmse

        i+=1
    avgRMSE = rmse_sum / 5
    print("sampleRatio:",sampleRatio)
#     print("Worst Model:",worstModel)
    print("Average Test Error(RMSE):",avgRMSE)
    stat[sampleRatio] = avgRMSE
# Out:
# sample size: 46
# sampleRatio: 0.001
# Average Test Error(RMSE): 15.474354610922267
# sample size: 4675
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2880: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)
# sampleRatio: 0.101
# Average Test Error(RMSE): 7.609020910315991
# sample size: 9304
# sampleRatio: 0.201
# Average Test Error(RMSE): 7.499773667749733
# sample size: 13933
# sampleRatio: 0.30100000000000005
# Average Test Error(RMSE): 7.501138684987206
# sample size: 18562
# sampleRatio: 0.401
# Average Test Error(RMSE): 7.430263654269597
# sample size: 23191
# sampleRatio: 0.501
# Average Test Error(RMSE): 7.363490210566201
# sample size: 27820
# sampleRatio: 0.6010000000000001
# Average Test Error(RMSE): 7.44010803657315
# sample size: 32449
# sampleRatio: 0.7010000000000001
# Average Test Error(RMSE): 7.39022099268568
# sample size: 37077
# sampleRatio: 0.801
# Average Test Error(RMSE): 7.484259960677802
# sample size: 41706
# sampleRatio: 0.901
# Average Test Error(RMSE): 7.3888722745757125

# %%
# %autoreload

targetCols = ['logDistance', 'logFrequency', 'logExtendedHeightTratio', 'season', 'pathloss']
xCols = ['logDistance', 'logFrequency', 'logExtendedHeightTratio', 'season',]
yCols = 'pathloss'
scale = "manual"
stat = {}

sampleRange = np.arange(0.001, 0.1, 0.005)
for sampleRatio in sampleRange:
    rmse_sum = 0

    addDataSampled = samplingData(addData[targetCols], sampleRatio, None, prFlag = False)
    # addDataSample.sort_values(by=['logDistance'])
    print("sample size:",addDataSampled['pathloss'].count())
    addDataNorm, normalizer = normalizeData(addDataSampled[targetCols], addDataSampled[yCols], scaler = scale, prFlag = False)

    X = np.array(addDataNorm[xCols])
    Xorigin = np.array(addData[xCols]) 
    Y = np.array(addDataSampled[yCols])

    kf = KFold(n_splits=5, shuffle=True)
    bestTestError = 0
    bestModel = None
    i = 1

    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = Y[train_index], Y[test_index]    
        model = ann_mlp_regression((60,), activation='logistic', optimizer='lbfgs')
        model.fit(X_train, y_train.flatten())

        pred_test = model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        mae = mean_absolute_error(y_test, pred_test)
        mape = mean_absolute_percentage_error(y_test, pred_test)
        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        r2 = r2_score(y_test, pred_test)
#         print("#"+str(i)+" Error(RMSE)-train:{} / test:{}".format(trainError,testError))     

        rmse_sum += rmse

        i+=1
    avgRMSE = rmse_sum / 5
    print("sampleRatio:",sampleRatio)
#     print("Worst Model:",worstModel)
    print("Average Test Error(RMSE):",avgRMSE)
    stat[sampleRatio] = avgRMSE
# Out:
# sample size: 46
# sampleRatio: 0.001
# Average Test Error(RMSE): 10.62379841860585
# sample size: 278
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2880: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)
# sampleRatio: 0.006
# Average Test Error(RMSE): 13.411532692375824
# sample size: 509
# sampleRatio: 0.011
# Average Test Error(RMSE): 11.397502364531585
# sample size: 741
# sampleRatio: 0.016
# Average Test Error(RMSE): 9.281143079115893
# sample size: 972
# sampleRatio: 0.021
# Average Test Error(RMSE): 8.946450219028462
# sample size: 1204
# sampleRatio: 0.026000000000000002
# Average Test Error(RMSE): 8.333272049421398
# sample size: 1435
# sampleRatio: 0.031
# Average Test Error(RMSE): 8.308241089326922
# sample size: 1666
# sampleRatio: 0.036000000000000004
# Average Test Error(RMSE): 8.103762685595257
# sample size: 1898
# sampleRatio: 0.041
# Average Test Error(RMSE): 7.994942700748335
# sample size: 2129
# sampleRatio: 0.046
# Average Test Error(RMSE): 7.967265345482479
# sample size: 2361
# sampleRatio: 0.051000000000000004
# Average Test Error(RMSE): 7.901680024951554
# sample size: 2592
# sampleRatio: 0.056
# Average Test Error(RMSE): 7.936406119583003
# sample size: 2824
# sampleRatio: 0.061
# Average Test Error(RMSE): 7.867832824717236
# sample size: 3055
# sampleRatio: 0.066
# Average Test Error(RMSE): 7.7658544058683905
# sample size: 3287
# sampleRatio: 0.07100000000000001
# Average Test Error(RMSE): 7.719875970677734
# sample size: 3518
# sampleRatio: 0.076
# Average Test Error(RMSE): 7.692196093833108
# sample size: 3749
# sampleRatio: 0.081
# Average Test Error(RMSE): 7.639986664175696
# sample size: 3981
# sampleRatio: 0.08600000000000001
# Average Test Error(RMSE): 7.725423211638878
# sample size: 4212
# sampleRatio: 0.096
# Average Test Error(RMSE): 7.619266184398464

# %%
print(stat)
# Out:
# {0.016: 9.281143079115893, 0.046: 7.967265345482479, 0.056: 7.936406119583003, 0.076: 7.692196093833108, 0.036000000000000004: 8.103762685595257, 0.091: 7.674203858928442, 0.096: 7.619266184398464, 0.011: 11.397502364531585, 0.081: 7.639986664175696, 0.061: 7.867832824717236, 0.026000000000000002: 8.333272049421398, 0.041: 7.994942700748335, 0.08600000000000001: 7.725423211638878, 0.066: 7.7658544058683905, 0.006: 13.411532692375824, 0.021: 8.946450219028462, 0.07100000000000001: 7.719875970677734, 0.051000000000000004: 7.901680024951554, 0.031: 8.308241089326922, 0.001: 10.62379841860585}

# %%
stat.update({0.00:15.47,0.10:7.61,0.20:7.50,0.30:7.50,0.40:7.43,0.50:7.36,0.60:7.44,0.70:7.39,0.80:7.48,0.90:7.39,0.016: 9.281143079115893, 0.046: 7.967265345482479, 0.056: 7.936406119583003, 0.076: 7.692196093833108, 0.036000000000000004: 8.103762685595257, 0.091: 7.674203858928442, 0.096: 7.619266184398464, 0.011: 11.397502364531585, 0.081: 7.639986664175696, 0.061: 7.867832824717236, 0.026000000000000002: 8.333272049421398, 0.041: 7.994942700748335, 0.08600000000000001: 7.725423211638878, 0.066: 7.7658544058683905, 0.006: 13.411532692375824, 0.021: 8.946450219028462, 0.07100000000000001: 7.719875970677734, 0.051000000000000004: 7.901680024951554, 0.031: 8.308241089326922, 0.001: 10.62379841860585})
df = pd.DataFrame(list(stat.items()), columns=['sampleRatio','RMSE']).sort_values(by=['sampleRatio'])
print(df)
df.plot.line(x='sampleRatio', y='RMSE')
# Out:
#     sampleRatio  RMSE
# 2          0.00 15.47
# 29         0.00 10.62
# 28         0.01 13.41
# 24         0.01 11.40
# 23         0.02  9.28
# 20         0.02  8.95
# 17         0.03  8.33
# 22         0.03  8.31
# 15         0.04  8.10
# 9          0.04  7.99
# 8          0.05  7.97
# 14         0.05  7.90
# 4          0.06  7.94
# 3          0.06  7.87
# 18         0.07  7.77
# 5          0.07  7.72
# 16         0.08  7.69
# 25         0.08  7.64
# 10         0.09  7.73
# 1          0.09  7.67
# 0          0.10  7.62
# 26         0.10  7.61
# 13         0.20  7.50
# 12         0.30  7.50
# 21         0.40  7.43
# 7          0.50  7.36
# 6          0.60  7.44
# 11         0.70  7.39
# 19         0.80  7.48
# 27         0.90  7.39

# %%
# %autoreload

wt_fileList = {'../data/PLdata_iksan_wt_400.csv':[('season', 0), ('frequency', 400), ('heightTB',30), ('heightB',15), ('heightM',2)],
            '../data/PLdata_iksan_wt_1399.csv':[('season', 0), ('frequency', 1399), ('heightTB',30), ('heightB',15), ('heightM',2)],
            '../data/PLdata_iksan_wt_2249.csv':[('season', 0), ('frequency', 2249), ('heightTB',30), ('heightB',15), ('heightM',2)]}
sp_fileList = {'../data/PLdata_iksan_sp_400.csv':[('season', 0.5), ('frequency', 400), ('heightTB',30), ('heightB',15), ('heightM',2)],
            '../data/PLdata_iksan_sp_1399.csv':[('season', 0.5), ('frequency', 1399), ('heightTB',30), ('heightB',15), ('heightM',2)],
            '../data/PLdata_iksan_sp_2249.csv':[('season', 0.5), ('frequency', 2249), ('heightTB',30), ('heightB',15), ('heightM',2)]}
sm_fileList = {'../data/PLdata_iksan_sm_400.csv':[('season', 1.0), ('frequency', 400), ('heightTB',30), ('heightB',15), ('heightM',2)],
            '../data/PLdata_iksan_sm_1399.csv':[('season', 1.0), ('frequency', 1399), ('heightTB',30), ('heightB',15), ('heightM',2)],
            '../data/PLdata_iksan_sm_2249.csv':[('season', 1.0), ('frequency', 2249), ('heightTB',30), ('heightB',15), ('heightM',2)]}
addWt = ADD_data_loader(wt_fileList)
print("winter data:",addWt.shape)
print("")
addSp = ADD_data_loader(sp_fileList)
print("spring data:",addSp.shape)
print("")
addSm = ADD_data_loader(sm_fileList)
print("summer data:",addSm.shape)
print("")

# print(addIksan.describe())
# print(addNonsan.describe())
# print(addPaju.describe())

addData = combineDF([addWt, addSp, addSm])
print("antenna_b height filtering-before(data count):",addData.shape)
addData = filteringDF(addData, 'heightTM', [10,100])
print("antenna_b height filtering-after(data count):",addData.shape)

print("freespace pathloss filtering-before(data count):",addData.shape)
addData['freePathloss'] = getFreeSpacePathLoss(addData['distance'],addData['frequency'])
addData = addData[addData['pathloss'] >= addData['freePathloss']]
print("freespace pathloss filtering-after(data count):",addData.shape)

# print("ADD data sample:\n",addData.head())
# Out:
# ADD data preprocessing
# ../data/PLdata_iksan_wt_400.csv: distance filtering(before):(109210, 4)
# ../data/PLdata_iksan_wt_400.csv: distance filtering(after):(10396, 4)
# ../data/PLdata_iksan_wt_2249.csv: distance filtering(before):(108873, 4)
# ../data/PLdata_iksan_wt_2249.csv: distance filtering(after):(10396, 4)
# ../data/PLdata_iksan_wt_1399.csv: distance filtering(before):(109060, 4)
# ../data/PLdata_iksan_wt_1399.csv: distance filtering(after):(10396, 4)
#           type  distance  pathloss  heightTM  season  frequency  heightTB  heightB  heightM
# type 6367    m      2.97    111.22      0.02       0        400        30       15        2
#      6368    m      2.96    115.43      0.02       0        400        30       15        2
#      6369    m      2.96    111.62      0.02       0        400        30       15        2
#      6370    m      2.95    108.95      0.02       0        400        30       15        2
#      6371    m      2.94    103.93      0.02       0        400        30       15        2
# Combined data set: (31188, 9)
# type filtering(before):(31188, 9)
# type filtering(after):(21210, 9)
# Dataframe before add new terms: (21210, 9)
# Dataframe after add constant feature: (21210, 20)
# winter data: (21210, 20)
#
# ADD data preprocessing
# ../data/PLdata_iksan_sp_400.csv: distance filtering(before):(106636, 4)
# ../data/PLdata_iksan_sp_400.csv: distance filtering(after):(14371, 4)
# ../data/PLdata_iksan_sp_2249.csv: distance filtering(before):(106493, 4)
# ../data/PLdata_iksan_sp_2249.csv: distance filtering(after):(14371, 4)
# ../data/PLdata_iksan_sp_1399.csv: distance filtering(before):(106570, 4)
# ../data/PLdata_iksan_sp_1399.csv: distance filtering(after):(14371, 4)
#          type  distance  pathloss  heightTM  season  frequency  heightTB  heightB  heightM
# type 400    m      1.02    100.42      0.01    0.50        400        30       15        2
#      401    m      1.02    100.39      0.01    0.50        400        30       15        2
#      402    m      1.02    100.39      0.01    0.50        400        30       15        2
#      403    m      1.03    100.39      0.01    0.50        400        30       15        2
#      404    m      1.03    100.46      0.01    0.50        400        30       15        2
# Combined data set: (43113, 9)
# type filtering(before):(43113, 9)
# type filtering(after):(28569, 9)
# Dataframe before add new terms: (28569, 9)
# Dataframe after add constant feature: (28569, 20)
# spring data: (28569, 20)
#
# ADD data preprocessing
# ../data/PLdata_iksan_sm_2249.csv: distance filtering(before):(111001, 4)
# ../data/PLdata_iksan_sm_2249.csv: distance filtering(after):(12759, 4)
# ../data/PLdata_iksan_sm_400.csv: distance filtering(before):(111256, 4)
# ../data/PLdata_iksan_sm_400.csv: distance filtering(after):(12759, 4)
# ../data/PLdata_iksan_sm_1399.csv: distance filtering(before):(111148, 4)
# ../data/PLdata_iksan_sm_1399.csv: distance filtering(after):(12759, 4)
#          type  distance  pathloss  heightTM  season  frequency  heightTB  heightB  heightM
# type 334    m      1.00    106.98      0.02    1.00       2249        30       15        2
#      335    m      1.02    110.96      0.02    1.00       2249        30       15        2
#      336    m      1.03    108.53      0.02    1.00       2249        30       15        2
#      337    m      1.03    108.90      0.02    1.00       2249        30       15        2
#      338    m      1.03    107.82      0.02    1.00       2249        30       15        2
# Combined data set: (38277, 9)
# type filtering(before):(38277, 9)
# type filtering(after):(26085, 9)
# Dataframe before add new terms: (26085, 9)
# Dataframe after add constant feature: (26085, 20)
# summer data: (26085, 20)
#
# antenna_b height filtering-before(data count): (75864, 20)
# antenna_b height filtering-after(data count): (67689, 20)
# freespace pathloss filtering-before(data count): (67689, 20)
# freespace pathloss filtering-after(data count): (65354, 20)

# %%
# %autoreload

targetCols = ['logDistance', 'logFrequency', 'logExtendedHeightTratio', 'season', 'pathloss']
xCols = ['logDistance', 'logFrequency', 'logExtendedHeightTratio', 'season',]
yCols = 'pathloss'
scale = "manual"
stat = {}

sampleRange = np.arange(0.001, 1.0, 0.1)
for sampleRatio in sampleRange:
    rmse_sum = 0

    addDataSampled = samplingData(addData[targetCols], sampleRatio, None, prFlag = False)
    # addDataSample.sort_values(by=['logDistance'])
    print("sample size:",addDataSampled['pathloss'].count())
    addDataNorm, normalizer = normalizeData(addDataSampled[targetCols], addDataSampled[yCols], scaler = scale, prFlag = False)

    X = np.array(addDataNorm[xCols])
    Xorigin = np.array(addData[xCols]) 
    Y = np.array(addDataSampled[yCols])

    kf = KFold(n_splits=5, shuffle=True)
    bestTestError = 0
    bestModel = None
    i = 1

    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = Y[train_index], Y[test_index]    
        model = ann_mlp_regression((60,), activation='logistic', optimizer='lbfgs')
        model.fit(X_train, y_train.flatten())

        pred_test = model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        mae = mean_absolute_error(y_test, pred_test)
        mape = mean_absolute_percentage_error(y_test, pred_test)
        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        r2 = r2_score(y_test, pred_test)
#         print("#"+str(i)+" Error(RMSE)-train:{} / test:{}".format(trainError,testError))     

        rmse_sum += rmse

        i+=1
    avgRMSE = rmse_sum / 5
    print("sampleRatio:",sampleRatio)
#     print("Worst Model:",worstModel)
    print("Average Test Error(RMSE):",avgRMSE)
    stat[sampleRatio] = avgRMSE
# Out:
# sample size: 65
# sampleRatio: 0.001
# Average Test Error(RMSE): 27.69225839571316
# sample size: 6601
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2880: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)
# sampleRatio: 0.101
# Average Test Error(RMSE): 14.312274946607792
# sample size: 13136
# sampleRatio: 0.201
# Average Test Error(RMSE): 13.979021061761955
# sample size: 19672
# sampleRatio: 0.30100000000000005
# Average Test Error(RMSE): 13.99456111415752
# sample size: 26207
# sampleRatio: 0.401
# Average Test Error(RMSE): 13.934953157613256
# sample size: 32742
# sampleRatio: 0.501
# Average Test Error(RMSE): 13.9409320763307
# sample size: 39278
# sampleRatio: 0.6010000000000001
# Average Test Error(RMSE): 13.997120975288354
# sample size: 45813
# sampleRatio: 0.7010000000000001
# Average Test Error(RMSE): 14.017102681936356
# sample size: 52349
# sampleRatio: 0.801
# Average Test Error(RMSE): 13.958796929900174
# sample size: 58884
# sampleRatio: 0.901
# Average Test Error(RMSE): 13.763468336777498

# %%
# %autoreload

targetCols = ['logDistance', 'logFrequency', 'logExtendedHeightTratio', 'season', 'pathloss']
xCols = ['logDistance', 'logFrequency', 'logExtendedHeightTratio', 'season',]
yCols = 'pathloss'
scale = "manual"
stat = {}

sampleRange = np.arange(0.001, 0.1, 0.005)
for sampleRatio in sampleRange:
    rmse_sum = 0

    addDataSampled = samplingData(addData[targetCols], sampleRatio, None, prFlag = False)
    # addDataSample.sort_values(by=['logDistance'])
    print("sample size:",addDataSampled['pathloss'].count())
    addDataNorm, normalizer = normalizeData(addDataSampled[targetCols], addDataSampled[yCols], scaler = scale, prFlag = False)

    X = np.array(addDataNorm[xCols])
    Xorigin = np.array(addData[xCols]) 
    Y = np.array(addDataSampled[yCols])

    kf = KFold(n_splits=5, shuffle=True)
    bestTestError = 0
    bestModel = None
    i = 1

    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = Y[train_index], Y[test_index]    
        model = ann_mlp_regression((60,), activation='logistic', optimizer='lbfgs')
        model.fit(X_train, y_train.flatten())

        pred_test = model.predict(X_test)

        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        mae = mean_absolute_error(y_test, pred_test)
        mape = mean_absolute_percentage_error(y_test, pred_test)
        rmse = np.sqrt(mean_squared_error(y_test, pred_test))
        r2 = r2_score(y_test, pred_test)
#         print("#"+str(i)+" Error(RMSE)-train:{} / test:{}".format(trainError,testError))     

        rmse_sum += rmse

        i+=1
    avgRMSE = rmse_sum / 5
    print("sampleRatio:",sampleRatio)
#     print("Worst Model:",worstModel)
    print("Average Test Error(RMSE):",avgRMSE)
    stat[sampleRatio] = avgRMSE
# Out:
# sample size: 65
# sampleRatio: 0.001
# Average Test Error(RMSE): 27.21732224209539
# sample size: 392
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2880: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return runner(coro)
# sampleRatio: 0.006
# Average Test Error(RMSE): 22.223509764229696
# sample size: 719
# sampleRatio: 0.011
# Average Test Error(RMSE): 17.812159338541075
# sample size: 1046
# sampleRatio: 0.016
# Average Test Error(RMSE): 16.036985419561333
# sample size: 1372
# sampleRatio: 0.021
# Average Test Error(RMSE): 15.765388522677762
# sample size: 1699
# sampleRatio: 0.026000000000000002
# Average Test Error(RMSE): 15.358669236580534
# sample size: 2026
# sampleRatio: 0.031
# Average Test Error(RMSE): 15.1819302396115
# sample size: 2353
# sampleRatio: 0.036000000000000004
# Average Test Error(RMSE): 15.266536264400353
# sample size: 2680
# sampleRatio: 0.041
# Average Test Error(RMSE): 14.842658542123402
# sample size: 3006
# sampleRatio: 0.046
# Average Test Error(RMSE): 14.59035928417733
# sample size: 3333
# sampleRatio: 0.051000000000000004
# Average Test Error(RMSE): 14.555240602804329
# sample size: 3660
# sampleRatio: 0.056
# Average Test Error(RMSE): 14.325971450781429
# sample size: 3987
# sampleRatio: 0.061
# Average Test Error(RMSE): 14.307766536094997
# sample size: 4313
# sampleRatio: 0.066
# Average Test Error(RMSE): 14.12551250961232
# sample size: 4640
# sampleRatio: 0.07100000000000001
# Average Test Error(RMSE): 14.350481635140898
# sample size: 4967
# sampleRatio: 0.076
# Average Test Error(RMSE): 14.228902021269391
# sample size: 5294
# sampleRatio: 0.081
# Average Test Error(RMSE): 14.242114196052347
# sample size: 5620
# sampleRatio: 0.08600000000000001
# Average Test Error(RMSE): 14.082874211663505
# sample size: 5947
# sampleRatio: 0.091
# Average Test Error(RMSE): 14.251187587516338
# sample size: 6274
# sampleRatio: 0.096
# Average Test Error(RMSE): 14.112759256290456

# %%
print(stat)
# Out:
# {0.016: 16.036985419561333, 0.046: 14.59035928417733, 0.056: 14.325971450781429, 0.076: 14.228902021269391, 0.036000000000000004: 15.266536264400353, 0.091: 14.251187587516338, 0.096: 14.112759256290456, 0.011: 17.812159338541075, 0.081: 14.242114196052347, 0.061: 14.307766536094997, 0.026000000000000002: 15.358669236580534, 0.041: 14.842658542123402, 0.08600000000000001: 14.082874211663505, 0.066: 14.12551250961232, 0.006: 22.223509764229696, 0.021: 15.765388522677762, 0.07100000000000001: 14.350481635140898, 0.051000000000000004: 14.555240602804329, 0.031: 15.1819302396115, 0.001: 27.21732224209539}

# %%
stat={0.00:27.69,0.10:14.31,0.20:13.98,0.30:13.99,0.40:13.93,0.50:13.94,0.60:14.00,0.70:14.02,0.80:13.96,0.90:13.76,0.016: 16.036985419561333, 0.046: 14.59035928417733, 0.056: 14.325971450781429, 0.076: 14.228902021269391, 0.036000000000000004: 15.266536264400353, 0.091: 14.251187587516338, 0.096: 14.112759256290456, 0.011: 17.812159338541075, 0.081: 14.242114196052347, 0.061: 14.307766536094997, 0.026000000000000002: 15.358669236580534, 0.041: 14.842658542123402, 0.08600000000000001: 14.082874211663505, 0.066: 14.12551250961232, 0.006: 22.223509764229696, 0.021: 15.765388522677762, 0.07100000000000001: 14.350481635140898, 0.051000000000000004: 14.555240602804329, 0.031: 15.1819302396115, 0.001: 27.21732224209539}
df = pd.DataFrame(list(stat.items()), columns=['sampleRatio','RMSE']).sort_values(by=['sampleRatio'])
print(df)
df.plot.line(x='sampleRatio', y='RMSE')
# Out:
#     sampleRatio  RMSE
# 0          0.00 27.69
# 23         0.00 27.22
# 26         0.01 22.22
# 16         0.01 17.81
# 13         0.02 16.04
# 9          0.02 15.77
# 14         0.03 15.36
# 11         0.03 15.18
# 15         0.04 15.27
# 19         0.04 14.84
# 21         0.05 14.59
# 28         0.05 14.56
# 5          0.06 14.33
# 4          0.06 14.31
# 7          0.07 14.13
# 3          0.07 14.35
# 22         0.08 14.23
# 17         0.08 14.24
# 20         0.09 14.08
# 29         0.09 14.25
# 25         0.10 14.11
# 1          0.10 14.31
# 27         0.20 13.98
# 6          0.30 13.99
# 18         0.40 13.93
# 2          0.50 13.94
# 12         0.60 14.00
# 24         0.70 14.02
# 8          0.80 13.96
# 10         0.90 13.76
